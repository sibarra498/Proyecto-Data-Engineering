# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Se carga el archivo csv

# %%
amazon_prime_tittles = pd.read_csv("amazon_prime_titles-score.csv")

# %% [markdown]
# Se observa la informacion que contiene el csv

# %%
amazon_prime_tittles.info
# Out:
# <bound method DataFrame.info of      show_id     type                    title         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                    cast         country  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#           date_added  release_year rating   duration                listed_in  \
# 0     March 30, 2021          2014    NaN    113 min            Comedy, Drama
# 1     March 30, 2021          2018    13+    110 min     Drama, International
# 2     March 30, 2021          2017    NaN     74 min  Action, Drama, Suspense
# 3     March 30, 2021          2014    NaN     69 min              Documentary
# 4     March 30, 2021          1989    NaN     45 min           Drama, Fantasy
# ...              ...           ...    ...        ...                      ...
# 9663             NaN          1940     7+     60 min                   Comedy
# 9664             NaN          2018    13+  4 Seasons                 TV Shows
# 9665             NaN          2008      R     90 min                   Action
# 9666             NaN          2021  TV-MA   1 Season            Drama, Sports
# 9667             NaN          2010      R    103 min  Action, Drama, Suspense
#
#                                             description  score
# 0     A small fishing village must procure a local d...     99
# 1     A Metro Family decides to fight a Cyber Crimin...     37
# 2     After a man discovers his wife is cheating on ...     20
# 3     Pink breaks the mold once again, bringing her ...     27
# 4     Teenage Matt Banting wants to work with a famo...     75
# ...                                                 ...    ...
# 9663  New York City street principles get an East Si...      7
# 9664  This is Earth, 2100AD - and these are the adve...     49
# 9665  In war-torn Eastern Europe, a world-weary grou...     68
# 9666  The series tells the story of Diego Maradona, ...     72
# 9667  Harry Brown, starring two-time Academy Award w...     30
#
# [9668 rows x 13 columns]>

# %% [markdown]
# Se crea una columna llamada "id", la cual contiene la letra inicial de la plataforma junto con el "show id". Por ejemplo la plataforma Amazon y el show id s1, la columna id sería igual a as1.

# %%
amazon_prime_tittles["id"] = "a" + amazon_prime_tittles["show_id"]

# %%
amazon_prime_tittles.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014    NaN  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017    NaN   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014    NaN   69 min              Documentary
# 4  March 30, 2021          1989    NaN   45 min           Drama, Fantasy
#
#                                          description  score   id
# 0  A small fishing village must procure a local d...     99  as1
# 1  A Metro Family decides to fight a Cyber Crimin...     37  as2
# 2  After a man discovers his wife is cheating on ...     20  as3
# 3  Pink breaks the mold once again, bringing her ...     27  as4
# 4  Teenage Matt Banting wants to work with a famo...     75  as5

# %% [markdown]
# Todos los valores nulos de la columna  rating se renombran con la letra "G"

# %%
amazon_prime_tittles["rating"].fillna("G", inplace = True)

# %%
amazon_prime_tittles.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  Movie   The Grand Seduction    Don McKellar
# 1      s2  Movie  Take Care Good Night    Girish Joshi
# 2      s3  Movie  Secrets of Deception     Josh Webber
# 3      s4  Movie    Pink: Staying True  Sonia Anderson
# 4      s5  Movie         Monster Maker    Giles Foster
#
#                                                 cast         country  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
#
#        date_added  release_year rating duration                listed_in  \
# 0  March 30, 2021          2014      G  113 min            Comedy, Drama
# 1  March 30, 2021          2018    13+  110 min     Drama, International
# 2  March 30, 2021          2017      G   74 min  Action, Drama, Suspense
# 3  March 30, 2021          2014      G   69 min              Documentary
# 4  March 30, 2021          1989      G   45 min           Drama, Fantasy
#
#                                          description  score   id
# 0  A small fishing village must procure a local d...     99  as1
# 1  A Metro Family decides to fight a Cyber Crimin...     37  as2
# 2  After a man discovers his wife is cheating on ...     20  as3
# 3  Pink breaks the mold once again, bringing her ...     27  as4
# 4  Teenage Matt Banting wants to work with a famo...     75  as5

# %% [markdown]
# Se convierten en minusculas todas las palabras contenidas en las columnas: type, title, director, cast, country, date addes, listed in, description.

# %%
amazon_prime_tittles["type"] = amazon_prime_tittles["type"].str.lower()
amazon_prime_tittles["title"] = amazon_prime_tittles["title"].str.lower()
amazon_prime_tittles["director"] = amazon_prime_tittles["director"].str.lower()
amazon_prime_tittles["cast"] = amazon_prime_tittles["cast"].str.lower()
amazon_prime_tittles["country"] = amazon_prime_tittles["country"].str.lower()
amazon_prime_tittles["date_added"] = amazon_prime_tittles["date_added"].str.lower()
amazon_prime_tittles["listed_in"] = amazon_prime_tittles["listed_in"].str.lower()
amazon_prime_tittles["description"] = amazon_prime_tittles["description"].str.lower()

# %%
amazon_prime_tittles.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      G  113 min            comedy, drama
# 1 2021-03-30          2018    13+  110 min     drama, international
# 2 2021-03-30          2017      G   74 min  action, drama, suspense
# 3 2021-03-30          2014      G   69 min              documentary
# 4 2021-03-30          1989      G   45 min           drama, fantasy
#
#                                          description  score   id duration_int  \
# 0  a small fishing village must procure a local d...     99  as1          113
# 1  a metro family decides to fight a cyber crimin...     37  as2          110
# 2  after a man discovers his wife is cheating on ...     20  as3           74
# 3  pink breaks the mold once again, bringing her ...     27  as4           69
# 4  teenage matt banting wants to work with a famo...     75  as5           45
#
#   duration_type Plataforma
# 0           min     amazon
# 1           min     amazon
# 2           min     amazon
# 3           min     amazon
# 4           min     amazon

# %% [markdown]
# Se separan en 2 la columna duration. Por un lado una columna contiene el tipo de dato (min, sesion) y por otro lado el numero asociado a la duracion

# %%
name=amazon_prime_tittles["duration"].str.split(expand=True)
name.columns=["duration_int", "duration_type"]
amazon_prime_tittles=pd.concat([amazon_prime_tittles, name], axis=1)

# %% [markdown]
# Se eliminda la columna duracion, pues ya quedo separada

# %%
amazon_prime_tittles.drop(["duration"], axis=1)
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      the grand seduction     don mckellar
# 1         s2    movie     take care good night     girish joshi
# 2         s3    movie     secrets of deception      josh webber
# 3         s4    movie       pink: staying true   sonia anderson
# 4         s5    movie            monster maker     giles foster
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      pride of the bowery  joseph h. lewis
# 9664   s9665  tv show            planet patrol              NaN
# 9665   s9666    movie                  outpost     steve barker
# 9666   s9667  tv show  maradona: blessed dream              NaN
# 9667   s9668    movie              harry brown    daniel barber
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2     tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3     interviews with: pink, adele, beyoncé, britney...   united states
# 4     harry dean stanton, kieran o'brien, george cos...  united kingdom
# ...                                                 ...             ...
# 9663                           leo gorcey, bobby jordan             NaN
# 9664  dick vosburgh, ronnie stevens, libby morris, m...             NaN
# 9665  ray stevenson, julian wadham, richard brake, m...             NaN
# 9666  esteban recagno, ezequiel stremiz, luciano vit...             NaN
# 9667  michael caine, emily mortimer, joseph gilgun, ...             NaN
#
#           date_added  release_year rating                listed_in  \
# 0     march 30, 2021          2014      G            comedy, drama
# 1     march 30, 2021          2018    13+     drama, international
# 2     march 30, 2021          2017      G  action, drama, suspense
# 3     march 30, 2021          2014      G              documentary
# 4     march 30, 2021          1989      G           drama, fantasy
# ...              ...           ...    ...                      ...
# 9663             NaN          1940     7+                   comedy
# 9664             NaN          2018    13+                 tv shows
# 9665             NaN          2008      R                   action
# 9666             NaN          2021  TV-MA            drama, sports
# 9667             NaN          2010      R  action, drama, suspense
#
#                                             description  score      id  \
# 0     a small fishing village must procure a local d...     99     as1
# 1     a metro family decides to fight a cyber crimin...     37     as2
# 2     after a man discovers his wife is cheating on ...     20     as3
# 3     pink breaks the mold once again, bringing her ...     27     as4
# 4     teenage matt banting wants to work with a famo...     75     as5
# ...                                                 ...    ...     ...
# 9663  new york city street principles get an east si...      7  as9664
# 9664  this is earth, 2100ad - and these are the adve...     49  as9665
# 9665  in war-torn eastern europe, a world-weary grou...     68  as9666
# 9666  the series tells the story of diego maradona, ...     72  as9667
# 9667  harry brown, starring two-time academy award w...     30  as9668
#
#      duration_int duration_type
# 0             113           min
# 1             110           min
# 2              74           min
# 3              69           min
# 4              45           min
# ...           ...           ...
# 9663           60           min
# 9664            4       Seasons
# 9665           90           min
# 9666            1        Season
# 9667          103           min
#
# [9668 rows x 15 columns]

# %% [markdown]
# Se cambia el formato de la columna date added al formato año/mes/dia

# %%
amazon_prime_tittles["date_added"] = pd.to_datetime(amazon_prime_tittles["date_added"])

# %%
amazon_prime_tittles.head()
# Out:
#   show_id   type                 title        director  \
# 0      s1  movie   the grand seduction    don mckellar
# 1      s2  movie  take care good night    girish joshi
# 2      s3  movie  secrets of deception     josh webber
# 3      s4  movie    pink: staying true  sonia anderson
# 4      s5  movie         monster maker    giles foster
#
#                                                 cast         country  \
# 0     brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1   mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2  tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3  interviews with: pink, adele, beyoncé, britney...   united states
# 4  harry dean stanton, kieran o'brien, george cos...  united kingdom
#
#   date_added  release_year rating duration                listed_in  \
# 0 2021-03-30          2014      G  113 min            comedy, drama
# 1 2021-03-30          2018    13+  110 min     drama, international
# 2 2021-03-30          2017      G   74 min  action, drama, suspense
# 3 2021-03-30          2014      G   69 min              documentary
# 4 2021-03-30          1989      G   45 min           drama, fantasy
#
#                                          description  score   id duration_int  \
# 0  a small fishing village must procure a local d...     99  as1          113
# 1  a metro family decides to fight a cyber crimin...     37  as2          110
# 2  after a man discovers his wife is cheating on ...     20  as3           74
# 3  pink breaks the mold once again, bringing her ...     27  as4           69
# 4  teenage matt banting wants to work with a famo...     75  as5           45
#
#   duration_type Plataforma duration_int duration_type
# 0           min     amazon          113           min
# 1           min     amazon          110           min
# 2           min     amazon           74           min
# 3           min     amazon           69           min
# 4           min     amazon           45           min

# %% [markdown]
# Se crea la columna respectiva para cada platafomra

# %%
amazon_prime_tittles["Plataforma"] = "amazon"

# %% [markdown]
# ETL del csv netflix

# %%
netflix_titles =pd.read_csv("netflix_titles-score.csv")
netflix_titles["id"] = "n" + netflix_titles["show_id"]
netflix_titles["rating"].fillna("G", inplace = True)

netflix_titles["type"] = netflix_titles["type"].str.lower()
netflix_titles["title"] = netflix_titles["title"].str.lower()
netflix_titles["director"] = netflix_titles["director"].str.lower()
netflix_titles["cast"] = netflix_titles["cast"].str.lower()
netflix_titles["country"] = netflix_titles["country"].str.lower()
netflix_titles["date_added"] = netflix_titles["date_added"].str.lower()
netflix_titles["listed_in"] = netflix_titles["listed_in"].str.lower()
netflix_titles["description"] = netflix_titles["description"].str.lower()

name=netflix_titles["duration"].str.split(expand=True)
name.columns=["duration_int", "duration_type"]
netflix_titles=pd.concat([netflix_titles, name], axis=1)
netflix_titles.drop(["duration"], axis=1)
netflix_titles["date_added"] = pd.to_datetime(netflix_titles["date_added"])
netflix_titles["Plataforma"] = "netflix"

# %% [markdown]
# ETL del csv Disney

# %%
disney_plus_titles = pd.read_csv("disney_plus_titles-score.csv")

disney_plus_titles["id"] = "d" + disney_plus_titles["show_id"]
disney_plus_titles["rating"].fillna("G", inplace = True)

disney_plus_titles["type"] = disney_plus_titles["type"].str.lower()
disney_plus_titles["title"] = disney_plus_titles["title"].str.lower()
disney_plus_titles["director"] = disney_plus_titles["director"].str.lower()
disney_plus_titles["cast"] = disney_plus_titles["cast"].str.lower()
disney_plus_titles["country"] = disney_plus_titles["country"].str.lower()
disney_plus_titles["date_added"] = disney_plus_titles["date_added"].str.lower()
disney_plus_titles["listed_in"] = disney_plus_titles["listed_in"].str.lower()
disney_plus_titles["description"] = disney_plus_titles["description"].str.lower()

name=disney_plus_titles["duration"].str.split(expand=True)
name.columns=["duration_int", "duration_type"]
disney_plus_titles=pd.concat([disney_plus_titles, name], axis=1)

disney_plus_titles.drop(["duration"], axis=1)

disney_plus_titles["date_added"] = pd.to_datetime(disney_plus_titles["date_added"])
disney_plus_titles["Plataforma"] = "disney"

# %% [markdown]
# ETL del csv Hulu

# %%
hulu_titles = pd.read_csv("hulu_titles-score (2).csv")

# %%
hulu_titles["id"] = "h" + hulu_titles["show_id"]
hulu_titles["rating"].fillna("G", inplace = True)
hulu_titles["type"] = hulu_titles["type"].str.lower()
hulu_titles["title"] = hulu_titles["title"].str.lower()
hulu_titles["director"] = hulu_titles["director"].str.lower()
#hulu_titles["cast"].str.lower()
hulu_titles["country"] = hulu_titles["country"].str.lower()
hulu_titles["date_added"] = hulu_titles["date_added"].str.lower()
hulu_titles["listed_in"] = hulu_titles["listed_in"].str.lower()
hulu_titles["description"] = hulu_titles["description"].str.lower()

name= hulu_titles["duration"].str.split(expand=True)
name.columns=["duration_int", "duration_type"]
hulu_titles=pd.concat([hulu_titles, name], axis=1)
hulu_titles.drop(["duration"], axis=1)

hulu_titles["date_added"] = pd.to_datetime(hulu_titles["date_added"])
hulu_titles["Plataforma"] = "hulu"

# %% [markdown]
# Se juntan todos los archivos csv despues de realizarles a cada uno un ETL, en un solo archivo que contenga toda la información, para posterior uso de la data

# %%
bases_datos = pd.concat([amazon_prime_tittles, disney_plus_titles, netflix_titles, hulu_titles])
bases_datos
# Out:
#      show_id     type                           title        director  \
# 0         s1    movie             the grand seduction    don mckellar
# 1         s2    movie            take care good night    girish joshi
# 2         s3    movie            secrets of deception     josh webber
# 3         s4    movie              pink: staying true  sonia anderson
# 4         s5    movie                   monster maker    giles foster
# ...      ...      ...                             ...             ...
# 3068   s3069  tv show  star trek: the original series             NaN
# 3069   s3070  tv show              star trek: voyager             NaN
# 3070   s3071  tv show                       the fades             NaN
# 3071   s3072  tv show               the twilight zone             NaN
# 3072   s3073  tv show             tokyo magnitude 8.0             NaN
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2     tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3     interviews with: pink, adele, beyoncé, britney...   united states
# 4     harry dean stanton, kieran o'brien, george cos...  united kingdom
# ...                                                 ...             ...
# 3068                                                NaN   united states
# 3069                                                NaN   united states
# 3070                                                NaN  united kingdom
# 3071                                                NaN   united states
# 3072                                                NaN           japan
#
#      date_added  release_year rating   duration  \
# 0    2021-03-30          2014      G    113 min
# 1    2021-03-30          2018    13+    110 min
# 2    2021-03-30          2017      G     74 min
# 3    2021-03-30          2014      G     69 min
# 4    2021-03-30          1989      G     45 min
# ...         ...           ...    ...        ...
# 3068        NaT          1966  TV-PG  3 Seasons
# 3069        NaT          1997  TV-PG  7 Seasons
# 3070        NaT          2011  TV-14   1 Season
# 3071        NaT          1959  TV-PG  5 Seasons
# 3072        NaT          2009  TV-14   1 Season
#
#                                    listed_in  \
# 0                              comedy, drama
# 1                       drama, international
# 2                    action, drama, suspense
# 3                                documentary
# 4                             drama, fantasy
# ...                                      ...
# 3068             action, adventure, classics
# 3069      action, adventure, science fiction
# 3070  horror, international, science fiction
# 3071     classics, science fiction, thriller
# 3072             anime, drama, international
#
#                                             description  score      id  \
# 0     a small fishing village must procure a local d...     99     as1
# 1     a metro family decides to fight a cyber crimin...     37     as2
# 2     after a man discovers his wife is cheating on ...     20     as3
# 3     pink breaks the mold once again, bringing her ...     27     as4
# 4     teenage matt banting wants to work with a famo...     75     as5
# ...                                                 ...    ...     ...
# 3068  the 23rd century adventures of captain james t...     14  hs3069
# 3069  catapulted into the distant sector of the gala...     53  hs3070
# 3070  seventeen-year-old paul is haunted by apocalyp...     81  hs3071
# 3071  rod serling's seminal anthology series focused...     81  hs3072
# 3072  the devastation is unleashed in the span of se...     47  hs3073
#
#      duration_int duration_type Plataforma
# 0             113           min     amazon
# 1             110           min     amazon
# 2              74           min     amazon
# 3              69           min     amazon
# 4              45           min     amazon
# ...           ...           ...        ...
# 3068            3       Seasons       hulu
# 3069            7       Seasons       hulu
# 3070            1        Season       hulu
# 3071            5       Seasons       hulu
# 3072            1        Season       hulu
#
# [22998 rows x 17 columns]

# %% [markdown]
# Cantidad de veces que aparece una keyword en el título de peliculas/series, por plataforma

# %%
def CountKey(plataforma, Keyword):
    #bases_datos.loc["Plataforma"]
    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b = db_b[db_b.title == Keyword]
    Numero = len(db_b)
    print (Numero)
    return Numero

# %%
def Get_Second_Score(plataforma):    
    db_b1 = bases_datos[(bases_datos.Plataforma == plataforma) & (bases_datos.type == "movie")]
    #db_b1 = bases_datos[]
    db_b2 = db_b1.sort_values('score', ascending=False)    
    
    #print(db_b2.iloc[0].score)
    try:
        db_b2 = db_b2[db_b2.score == db_b2.iloc[1].score]
    except:
        print("La plataforma de busqueda no fue encontrada¡¡")
        return "Error"
    db_b2 = db_b2.sort_values(by = 'title', ascending=True)
    #print(db_b2)
    #print(db_b2)
    try: 
        pelicula2 = db_b2.iloc[1].title
    except: 
        pelicula2 = db_b2.iloc[0].title
    scoreM = db_b2.iloc[0].score
    #print(pelicula2, "score: ", db_b2.iloc[0].score)
    return pelicula2, scoreM

# %% [markdown]
# Cantidad de series y películas por rating

# %%
def longest(plataforma, duration_type, year):
    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b1 = db_b[db_b.duration_type == duration_type]
    db_b2 = db_b1[db_b1.release_year == year].reset_index()
    db_b2.duration_int = db_b2.duration_int.astype(int)
    #db_b2.convert_dtypes(convert_string=False)
    #print(db_b2)
    db3 = db_b2.sort_values(by = 'duration_int', ascending=False)
    #for i in db3.duration_int:
        #print(i, type(i))
    #print(db3)
    peliculaMax = db3.iloc[0].title
    #print(max(db_b2.duration_int))
    #print(d)
    #db_b2[db_b2.duration_int.max()], db_b2[db_b2["duration_type"]]
    return peliculaMax, db3.iloc[0].duration_int
longest("netflix", "min", 2016)
# Out:
# ('sairat', 173)

# %% [markdown]
# Cantidad de series y películas por rating

# %%
def rating_count(rating):
    db_b = bases_datos[bases_datos.rating == rating]
    Numero = len(db_b)
    print ("rating: ",rating, "cantidad: ",Numero)
    return Numero
rating_count("18+")
# Out:
# rating:  18+ cantidad:  1243
# 1243

# %% [markdown]
# Cantidad de películas por plataforma con un puntaje mayor a XX en determinado año

# %%
def score_count (plataforma, score, year):
    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b1 = db_b[db_b.release_year == year]
    db_b2 = db_b1[db_b1.score > score]
    Numero = len(db_b2)
    print("plataforma: ",plataforma, "cantidad: ", Numero)

score_count("netflix", 85, 2010)
# Out:
# plataforma:  netflix cantidad:  25

# %% [markdown]
# FastAPI

# %%
from fastapi import FastAPI, Form
app = FastAPI(title="Proyecto Data Engiennering")

app = FastAPI()

@app.get('/')
async def root():
    return "Hello, listo pa probar esta poderosa api?"

def crearBases():
    amazon_prime_tittles = pd.read_csv("amazon_prime_titles-score.csv")

    amazon_prime_tittles["id"] = "a" + amazon_prime_tittles["show_id"]
    amazon_prime_tittles["rating"].fillna("G", inplace = True)

    amazon_prime_tittles["type"] = amazon_prime_tittles["type"].str.lower()
    amazon_prime_tittles["title"] = amazon_prime_tittles["title"].str.lower()
    amazon_prime_tittles["director"] = amazon_prime_tittles["director"].str.lower()
    amazon_prime_tittles["cast"] = amazon_prime_tittles["cast"].str.lower()
    amazon_prime_tittles["country"] = amazon_prime_tittles["country"].str.lower()
    amazon_prime_tittles["date_added"] = amazon_prime_tittles["date_added"].str.lower()
    amazon_prime_tittles["listed_in"] = amazon_prime_tittles["listed_in"].str.lower()
    amazon_prime_tittles["description"] = amazon_prime_tittles["description"].str.lower()

    name=amazon_prime_tittles["duration"].str.split(expand=True)
    name.columns=["duration_int", "duration_type"]
    amazon_prime_tittles=pd.concat([amazon_prime_tittles, name], axis=1)

    amazon_prime_tittles.drop(["duration"], axis=1)

    amazon_prime_tittles["date_added"] = pd.to_datetime(amazon_prime_tittles["date_added"])
    amazon_prime_tittles["Plataforma"] = "amazon"
    amazon_prime_tittles["release_year"].min()

    #amazon_prime_tittles.head()
    print(amazon_prime_tittles)


    disney_plus_titles = pd.read_csv("disney_plus_titles-score.csv")

    disney_plus_titles["id"] = "d" + disney_plus_titles["show_id"]
    disney_plus_titles["rating"].fillna("G", inplace = True)

    disney_plus_titles["type"] = disney_plus_titles["type"].str.lower()
    disney_plus_titles["title"] = disney_plus_titles["title"].str.lower()
    disney_plus_titles["director"] = disney_plus_titles["director"].str.lower()
    disney_plus_titles["cast"] = disney_plus_titles["cast"].str.lower()
    disney_plus_titles["country"] = disney_plus_titles["country"].str.lower()
    disney_plus_titles["date_added"] = disney_plus_titles["date_added"].str.lower()
    disney_plus_titles["listed_in"] = disney_plus_titles["listed_in"].str.lower()
    disney_plus_titles["description"] = disney_plus_titles["description"].str.lower()

    name=disney_plus_titles["duration"].str.split(expand=True)
    name.columns=["duration_int", "duration_type"]
    disney_plus_titles=pd.concat([disney_plus_titles, name], axis=1)

    disney_plus_titles.drop(["duration"], axis=1)

    disney_plus_titles["date_added"] = pd.to_datetime(disney_plus_titles["date_added"])
    disney_plus_titles["Plataforma"] = "disney"
    disney_plus_titles["release_year"].min()

    disney_plus_titles.head()
    print(disney_plus_titles)


    netflix_titles =pd.read_csv("netflix_titles-score.csv")
    netflix_titles["id"] = "a" + netflix_titles["show_id"]
    netflix_titles["rating"].fillna("G", inplace = True)

    netflix_titles["type"] = netflix_titles["type"].str.lower()
    netflix_titles["title"] = netflix_titles["title"].str.lower()
    netflix_titles["director"] = netflix_titles["director"].str.lower()
    netflix_titles["cast"] = netflix_titles["cast"].str.lower()
    netflix_titles["country"] = netflix_titles["country"].str.lower()
    netflix_titles["date_added"] = netflix_titles["date_added"].str.lower()
    netflix_titles["listed_in"] = netflix_titles["listed_in"].str.lower()
    netflix_titles["description"] = netflix_titles["description"].str.lower()

    name=netflix_titles["duration"].str.split(expand=True)
    name.columns=["duration_int", "duration_type"]
    netflix_titles=pd.concat([netflix_titles, name], axis=1)
    netflix_titles.drop(["duration"], axis=1)
    netflix_titles["date_added"] = pd.to_datetime(netflix_titles["date_added"])
    netflix_titles["Plataforma"] = "netflix"
    netflix_titles.head()

    hulu_titles = pd.read_csv("hulu_titles-score (2).csv")

    hulu_titles["id"] = "h" + hulu_titles["show_id"]
    hulu_titles["rating"].fillna("G", inplace = True)
    hulu_titles["type"] = hulu_titles["type"].str.lower()
    hulu_titles["title"] = hulu_titles["title"].str.lower()
    hulu_titles["director"] = hulu_titles["director"].str.lower()
    #hulu_titles["cast"].str.lower()
    hulu_titles["country"] = hulu_titles["country"].str.lower()
    hulu_titles["date_added"] = hulu_titles["date_added"].str.lower()
    hulu_titles["listed_in"] = hulu_titles["listed_in"].str.lower()
    hulu_titles["description"] = hulu_titles["description"].str.lower()

    name= hulu_titles["duration"].str.split(expand=True)
    name.columns=["duration_int", "duration_type"]
    hulu_titles=pd.concat([hulu_titles, name], axis=1)
    hulu_titles.drop(["duration"], axis=1)

    hulu_titles["date_added"] = pd.to_datetime(hulu_titles["date_added"])
    hulu_titles["Plataforma"] = "hulu"


    bases_datos = pd.concat([amazon_prime_tittles, disney_plus_titles, netflix_titles, hulu_titles])
    #bases_datos

    return bases_datos
bases_datos = crearBases()

#Cantidad de veces que aparece una keyword en el título de peliculas/series, por plataforma
#@app.route('/CountKey', methods=["GET"])
@app.post("/CountKey")
async def login(plataforma: str = Form(), Keyword: str = Form()):
#def CountKey():
    #plataforma = request.form.get('plataforma')
    #Keyword = request.form.get('Keyword')
    print (plataforma) #, Keyword)
    #bases_datos.loc["Plataforma"]
    '''
    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b = db_b.loc[[True if Keyword in title else False for title in db_b["title"]]]
    #print (db_b)    
    Numero = len(db_b)
    '''
    Numero = "mrd"
    #print (Numero)
    return {
        "plataforma": plataforma,
        "Keywords": Keyword
    }
    #return Numero
#CountKey("netflix", "love")


#Cantidad de películas por plataforma con un puntaje mayor a XX en determinado año
@app.get('/score_count')
async def score_count():
#def score_count (plataforma, score, year):
    plataforma = "netflix"
    year = 2010
    score = 85

    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b1 = db_b[db_b.release_year == year]
    db_b2 = db_b1[db_b1.score > score]
    Numero = len(db_b2)
    print("plataforma: ",plataforma, "cantidad: ", Numero)
    return Numero
#score_count("netflix", 85, 2010)

@app.get('/Get_Second_Score')
def Get_Second_Score(plataforma):   
    db_b1 = bases_datos[(bases_datos.Plataforma == plataforma) & (bases_datos.type == "movie")]
    #db_b1 = bases_datos[]
    db_b2 = db_b1.sort_values('score', ascending=False) 
    
    #print(db_b2.iloc[0].score)
    try:
        db_b2 = db_b2[db_b2.score == db_b2.iloc[1].score]
    except:
        print("La plataforma de busqueda no fue encontrada¡¡")
        return "Error"
    db_b2 = db_b2.sort_values(by = 'title', ascending=True)
    #print(db_b2)
    #print(db_b2)
    try: 
        pelicula2 = db_b2.iloc[1].title
    except: 
        pelicula2 = db_b2.iloc[0].title
    scoreM = db_b2.iloc[0].score
    #print(pelicula2, "score: ", db_b2.iloc[0].score)
    return pelicula2 #, scoreM
#Get_Second_Score("amazon")


#Cantidad de series y películas por rating
@app.get('/longest')
def longest(plataforma, duration_type, year):
    db_b = bases_datos[bases_datos.Plataforma == plataforma]
    db_b1 = db_b[db_b.duration_type == duration_type]
    db_b2 = db_b1[db_b1.release_year == year].reset_index()
    db_b2.duration_int = db_b2.duration_int.astype(int)
    #db_b2.convert_dtypes(convert_string=False)
    #print(db_b2)
    db3 = db_b2.sort_values(by = 'duration_int', ascending=False)
    #for i in db3.duration_int:
        #print(i, type(i))
    #print(db3)
    peliculaMax = db3.iloc[0].title
    #print(max(db_b2.duration_int))
    #print(d)
    #db_b2[db_b2.duration_int.max()], db_b2[db_b2["duration_type"]]
    return peliculaMax #, db3.iloc[0].duration_int
#longest("netflix", "min", 2016)

@app.get('/rating_count')
def rating_count(rating):
    db_b = bases_datos[bases_datos.rating == rating]
    Numero = len(db_b)
    print ("rating: ",rating, "\ncantidad: ",Numero)
    return Numero
#rating_count("18+")
# Out:
#      show_id     type                    title         director  \
# 0         s1    movie      the grand seduction     don mckellar
# 1         s2    movie     take care good night     girish joshi
# 2         s3    movie     secrets of deception      josh webber
# 3         s4    movie       pink: staying true   sonia anderson
# 4         s5    movie            monster maker     giles foster
# ...      ...      ...                      ...              ...
# 9663   s9664    movie      pride of the bowery  joseph h. lewis
# 9664   s9665  tv show            planet patrol              NaN
# 9665   s9666    movie                  outpost     steve barker
# 9666   s9667  tv show  maradona: blessed dream              NaN
# 9667   s9668    movie              harry brown    daniel barber
#
#                                                    cast         country  \
# 0        brendan gleeson, taylor kitsch, gordon pinsent          canada
# 1      mahesh manjrekar, abhay mahajan, sachin khedekar           india
# 2     tom sizemore, lorenzo lamas, robert lasardo, r...   united states
# 3     interviews with: pink, adele, beyoncé, britney...   united states
# 4     harry dean stanton, kieran o'brien, george cos...  united kingdom
# ...                                                 ...             ...
# 9663                           leo gorcey, bobby jordan             NaN
# 9664  dick vosburgh, ronnie stevens, libby morris, m...             NaN
# 9665  ray stevenson, julian wadham, richard brake, m...             NaN
# 9666  esteban recagno, ezequiel stremiz, luciano vit...             NaN
# 9667  michael caine, emily mortimer, joseph gilgun, ...             NaN
#
#      date_added  release_year rating   duration                listed_in  \
# 0    2021-03-30          2014      G    113 min            comedy, drama
# 1    2021-03-30          2018    13+    110 min     drama, international
# 2    2021-03-30          2017      G     74 min  action, drama, suspense
# 3    2021-03-30          2014      G     69 min              documentary
# 4    2021-03-30          1989      G     45 min           drama, fantasy
# ...         ...           ...    ...        ...                      ...
# 9663        NaT          1940     7+     60 min                   comedy
# 9664        NaT          2018    13+  4 Seasons                 tv shows
# 9665        NaT          2008      R     90 min                   action
# 9666        NaT          2021  TV-MA   1 Season            drama, sports
# 9667        NaT          2010      R    103 min  action, drama, suspense
#
#                                             description  score      id  \
# 0     a small fishing village must procure a local d...     99     as1
# 1     a metro family decides to fight a cyber crimin...     37     as2
# 2     after a man discovers his wife is cheating on ...     20     as3
# 3     pink breaks the mold once again, bringing her ...     27     as4
# 4     teenage matt banting wants to work with a famo...     75     as5
# ...                                                 ...    ...     ...
# 9663  new york city street principles get an east si...      7  as9664
# 9664  this is earth, 2100ad - and these are the adve...     49  as9665
# 9665  in war-torn eastern europe, a world-weary grou...     68  as9666
# 9666  the series tells the story of diego maradona, ...     72  as9667
# 9667  harry brown, starring two-time academy award w...     30  as9668
#
#      duration_int duration_type Plataforma
# 0             113           min     amazon
# 1             110           min     amazon
# 2              74           min     amazon
# 3              69           min     amazon
# 4              45           min     amazon
# ...           ...           ...        ...
# 9663           60           min     amazon
# 9664            4       Seasons     amazon
# 9665           90           min     amazon
# 9666            1        Season     amazon
# 9667          103           min     amazon
#
# [9668 rows x 17 columns]
#      show_id     type                                             title  \
# 0         s1    movie  duck the halls: a mickey mouse christmas special
# 1         s2    movie                            ernest saves christmas
# 2         s3    movie                      ice age: a mammoth christmas
# 3         s4    movie                        the queen family singalong
# 4         s5  tv show                             the beatles: get back
# ...      ...      ...                                               ...
# 1445   s1446    movie                          x-men origins: wolverine
# 1446   s1447    movie    night at the museum: battle of the smithsonian
# 1447   s1448    movie                                   eddie the eagle
# 1448   s1449    movie                              bend it like beckham
# 1449   s1450    movie             captain sparky vs. the flying saucers
#
#                                director  \
# 0     alonso ramirez ramos, dave wasson
# 1                           john cherry
# 2                          karen disher
# 3                       hamish hamilton
# 4                                   NaN
# ...                                 ...
# 1445                         gavin hood
# 1446                         shawn levy
# 1447                    dexter fletcher
# 1448                    gurinder chadha
# 1449                        mark waring
#
#                                                    cast  \
# 0     chris diamantopoulos, tony anselmo, tress macn...
# 1              jim varney, noelle parker, douglas seale
# 2     raymond albert romano, john leguizamo, denis l...
# 3     darren criss, adam lambert, derek hough, alexa...
# 4     john lennon, paul mccartney, george harrison, ...
# ...                                                 ...
# 1445  hugh jackman, liev schreiber, danny huston, wi...
# 1446  ben stiller, amy adams, owen wilson, hank azar...
# 1447  tom costello, jo hartley, keith allen, dickon ...
# 1448  parminder nagra, keira knightley, jonathan rhy...
# 1449                                      charlie tahan
#
#                                      country date_added  release_year rating  \
# 0                                        NaN 2021-11-26          2016   TV-G
# 1                                        NaN 2021-11-26          1988     PG
# 2                              united states 2021-11-26          2011   TV-G
# 3                                        NaN 2021-11-26          2021  TV-PG
# 4                                        NaN 2021-11-25          2021      G
# ...                                      ...        ...           ...    ...
# 1445           united states, united kingdom 2021-06-04          2009  PG-13
# 1446                   united states, canada 2021-04-02          2009     PG
# 1447  united kingdom, germany, united states 2020-12-18          2016  PG-13
# 1448  united kingdom, germany, united states 2020-09-18          2003  PG-13
# 1449                           united states 2020-04-01          2012   TV-G
#
#       duration                                      listed_in  \
# 0       23 min                              animation, family
# 1       91 min                                         comedy
# 2       23 min                      animation, comedy, family
# 3       41 min                                        musical
# 4     1 Season                  docuseries, historical, music
# ...        ...                                            ...
# 1445   108 min      action-adventure, family, science fiction
# 1446   106 min               action-adventure, comedy, family
# 1447   107 min                    biographical, comedy, drama
# 1448   112 min                   buddy, comedy, coming of age
# 1449     2 min  action-adventure, animals & nature, animation
#
#                                             description  score      id  \
# 0      join mickey and the gang as they duck the halls!    100     ds1
# 1     santa claus passes his magic bag to a new st. ...     17     ds2
# 2             sid the sloth is on santa's naughty list.     92     ds3
# 3                  this is real life, not just fantasy!     35     ds4
# 4     a three-part documentary from peter jackson ca...     11     ds5
# ...                                                 ...    ...     ...
# 1445  wolverine unites with legendary x-men to fight...     53  ds1446
# 1446  larry daley returns to rescue some old friends...     75  ds1447
# 1447  true story of eddie edwards, a british ski-jum...     89  ds1448
# 1448  despite the wishes of their traditional famili...     77  ds1449
# 1449         view one of sparky's favorite home movies.     88  ds1450
#
#      duration_int duration_type Plataforma
# 0              23           min     disney
# 1              91           min     disney
# 2              23           min     disney
# 3              41           min     disney
# 4               1        Season     disney
# ...           ...           ...        ...
# 1445          108           min     disney
# 1446          106           min     disney
# 1447          107           min     disney
# 1448          112           min     disney
# 1449            2           min     disney
#
# [1450 rows x 17 columns]
# Form data requires "python-multipart" to be installed.
# You can install "python-multipart" with:
#
# pip install python-multipart
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# c:\Users\ASUS\Desktop\Henry\labs\py1 2.0\pry1.ipynb Cell 41 in <cell line: 118>()
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=113'>114</a> bases_datos = crearBases()
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=115'>116</a> #Cantidad de veces que aparece una keyword en el título de peliculas/series, por plataforma
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=116'>117</a> #@app.route('/CountKey', methods=["GET"])
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=117'>118</a> @app.post("/CountKey")
# --> <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=118'>119</a> async def login(plataforma: str = Form(), Keyword: str = Form()):
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=119'>120</a> #def CountKey():
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=120'>121</a>     #plataforma = request.form.get('plataforma')
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=121'>122</a>     #Keyword = request.form.get('Keyword')
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=122'>123</a>     print (plataforma) #, Keyword)
#     <a href='vscode-notebook-cell:/c%3A/Users/ASUS/Desktop/Henry/labs/py1%202.0/pry1.ipynb#X41sZmlsZQ%3D%3D?line=123'>124</a>     #bases_datos.loc["Plataforma"]
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\fastapi\routing.py:638, in APIRouter.api_route.<locals>.decorator(func)
#     637 def decorator(func: DecoratedCallable) -> DecoratedCallable:
# --> 638     self.add_api_route(
#     639         path,
#     640         func,
#     641         response_model=response_model,
#     642         status_code=status_code,
#     643         tags=tags,
#     644         dependencies=dependencies,
#     645         summary=summary,
#     646         description=description,
#     647         response_description=response_description,
#     648         responses=responses,
#     649         deprecated=deprecated,
#     650         methods=methods,
#     651         operation_id=operation_id,
#     652         response_model_include=response_model_include,
#     653         response_model_exclude=response_model_exclude,
#     654         response_model_by_alias=response_model_by_alias,
#     655         response_model_exclude_unset=response_model_exclude_unset,
#     656         response_model_exclude_defaults=response_model_exclude_defaults,
#     657         response_model_exclude_none=response_model_exclude_none,
#     658         include_in_schema=include_in_schema,
#     659         response_class=response_class,
#     660         name=name,
#     661         callbacks=callbacks,
#     662         openapi_extra=openapi_extra,
#     663         generate_unique_id_function=generate_unique_id_function,
#     664     )
#     665     return func
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\fastapi\routing.py:577, in APIRouter.add_api_route(self, path, endpoint, response_model, status_code, tags, dependencies, summary, description, response_description, responses, deprecated, methods, operation_id, response_model_include, response_model_exclude, response_model_by_alias, response_model_exclude_unset, response_model_exclude_defaults, response_model_exclude_none, include_in_schema, response_class, name, route_class_override, callbacks, openapi_extra, generate_unique_id_function)
#     573     current_callbacks.extend(callbacks)
#     574 current_generate_unique_id = get_value_or_default(
#     575     generate_unique_id_function, self.generate_unique_id_function
#     576 )
# --> 577 route = route_class(
#     578     self.prefix + path,
#     579     endpoint=endpoint,
#     580     response_model=response_model,
#     581     status_code=status_code,
#     582     tags=current_tags,
#     583     dependencies=current_dependencies,
#     584     summary=summary,
#     585     description=description,
#     586     response_description=response_description,
#     587     responses=combined_responses,
#     588     deprecated=deprecated or self.deprecated,
#     589     methods=methods,
#     590     operation_id=operation_id,
#     591     response_model_include=response_model_include,
#     592     response_model_exclude=response_model_exclude,
#     593     response_model_by_alias=response_model_by_alias,
#     594     response_model_exclude_unset=response_model_exclude_unset,
#     595     response_model_exclude_defaults=response_model_exclude_defaults,
#     596     response_model_exclude_none=response_model_exclude_none,
#     597     include_in_schema=include_in_schema and self.include_in_schema,
#     598     response_class=current_response_class,
#     599     name=name,
#     600     dependency_overrides_provider=self.dependency_overrides_provider,
#     601     callbacks=current_callbacks,
#     602     openapi_extra=openapi_extra,
#     603     generate_unique_id_function=current_generate_unique_id,
#     604 )
#     605 self.routes.append(route)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\fastapi\routing.py:452, in APIRoute.__init__(self, path, endpoint, response_model, status_code, tags, dependencies, summary, description, response_description, responses, deprecated, name, methods, operation_id, response_model_include, response_model_exclude, response_model_by_alias, response_model_exclude_unset, response_model_exclude_defaults, response_model_exclude_none, include_in_schema, response_class, dependency_overrides_provider, callbacks, openapi_extra, generate_unique_id_function)
#     447 for depends in self.dependencies[::-1]:
#     448     self.dependant.dependencies.insert(
#     449         0,
#     450         get_parameterless_sub_dependant(depends=depends, path=self.path_format),
#     451     )
# --> 452 self.body_field = get_body_field(dependant=self.dependant, name=self.unique_id)
#     453 self.app = request_response(self.get_route_handler())
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\fastapi\dependencies\utils.py:766, in get_body_field(dependant, name)
#     758         BodyFieldInfo_kwargs["media_type"] = body_param_media_types[0]
#     759 final_field = create_response_field(
#     760     name="body",
#     761     type_=BodyModel,
#    (...)
#     764     field_info=BodyFieldInfo(**BodyFieldInfo_kwargs),
#     765 )
# --> 766 check_file_field(final_field)
#     767 return final_field
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\fastapi\dependencies\utils.py:111, in check_file_field(field)
#     109 except ImportError:
#     110     logger.error(multipart_not_installed_error)
# --> 111     raise RuntimeError(multipart_not_installed_error) from None
#
# RuntimeError: Form data requires "python-multipart" to be installed.
# You can install "python-multipart" with:
#
# pip install python-multipart
